# %% [markdown]
# CSYE7105 High Performance Parallel Machine Learning and AI
#
# Instructor: Dr. Handan Liu
#
# Example: GridSearch CV in parallel

# %%
import numpy as np
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.datasets import make_classification
from time import time

# %%
X_train, y_train = make_classification(n_samples=int(10000), n_features=50, random_state=0)

# %%
model = ExtraTreesClassifier(class_weight='balanced')
parameters = {'criterion': ['gini', 'entropy'],
                       'min_samples_split' : [2, 4, 8],
                       'max_depth' : [3, 10, 20]}

# %%
start = time()
clf = GridSearchCV(model, parameters, verbose=3, scoring='roc_auc', cv=StratifiedKFold(shuffle=True), n_jobs=4)
clf.fit(X_train, y_train)
elapsed = time() - start
print('Elasped time: ', elapsed)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5] END criterion=gini, max_depth=3, min_samples_split=2;, score=0.914 total time=   1.2s
# [CV 2/5] END criterion=gini, max_depth=3, min_samples_split=2;, score=0.909 total time=   1.1s
# [CV 4/5] END criterion=gini, max_depth=3, min_samples_split=2;, score=0.896 total time=   1.1s
# [CV 3/5] END criterion=gini, max_depth=3, min_samples_split=2;, score=0.903 total time=   1.3s
# [CV 5/5] END criterion=gini, max_depth=3, min_samples_split=2;, score=0.905 total time=   1.1s
# [CV 2/5] END criterion=gini, max_depth=3, min_samples_split=4;, score=0.889 total time=   1.1s
# [CV 1/5] END criterion=gini, max_depth=3, min_samples_split=4;, score=0.915 total time=   1.1s
# [CV 3/5] END criterion=gini, max_depth=3, min_samples_split=4;, score=0.894 total time=   1.3s
# [CV 4/5] END criterion=gini, max_depth=3, min_samples_split=4;, score=0.910 total time=   1.1s
# [CV 5/5] END criterion=gini, max_depth=3, min_samples_split=4;, score=0.925 total time=   1.1s
# [CV 1/5] END criterion=gini, max_depth=3, min_samples_split=8;, score=0.909 total time=   1.1s
# [CV 2/5] END criterion=gini, max_depth=3, min_samples_split=8;, score=0.913 total time=   1.1s
# [CV 4/5] END criterion=gini, max_depth=3, min_samples_split=8;, score=0.894 total time=   1.1s
# [CV 5/5] END criterion=gini, max_depth=3, min_samples_split=8;, score=0.909 total time=   1.1s
# [CV 3/5] END criterion=gini, max_depth=3, min_samples_split=8;, score=0.883 total time=   1.3s
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_split=2;, score=0.952 total time=   2.5s
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_split=2;, score=0.948 total time=   2.5s
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_split=2;, score=0.948 total time=   2.5s
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_split=2;, score=0.948 total time=   2.6s
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_split=2;, score=0.955 total time=   2.5s
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_split=4;, score=0.956 total time=   2.5s
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_split=4;, score=0.951 total time=   2.5s
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_split=4;, score=0.944 total time=   2.6s
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_split=4;, score=0.953 total time=   2.5s
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_split=4;, score=0.949 total time=   2.5s
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_split=8;, score=0.953 total time=   2.5s
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_split=8;, score=0.947 total time=   2.5s
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_split=8;, score=0.948 total time=   2.6s
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_split=8;, score=0.948 total time=   2.5s
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_split=8;, score=0.951 total time=   2.5s
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_split=2;, score=0.963 total time=   4.5s
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_split=2;, score=0.960 total time=   4.6s
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_split=2;, score=0.959 total time=   4.5s
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_split=2;, score=0.961 total time=   4.6s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_split=2;, score=0.964 total time=   4.4s
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_split=4;, score=0.963 total time=   4.3s
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_split=4;, score=0.961 total time=   4.3s
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_split=4;, score=0.962 total time=   4.6s
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_split=4;, score=0.959 total time=   4.4s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_split=4;, score=0.964 total time=   4.4s
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_split=8;, score=0.964 total time=   4.2s
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_split=8;, score=0.962 total time=   4.2s
# [CV 1/5] END criterion=entropy, max_depth=3, min_samples_split=2;, score=0.895 total time=   1.1s
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_split=8;, score=0.961 total time=   4.3s
# [CV 2/5] END criterion=entropy, max_depth=3, min_samples_split=2;, score=0.903 total time=   1.1s
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_split=8;, score=0.959 total time=   4.2s
# [CV 4/5] END criterion=entropy, max_depth=3, min_samples_split=2;, score=0.918 total time=   1.1s
# [CV 3/5] END criterion=entropy, max_depth=3, min_samples_split=2;, score=0.915 total time=   1.3s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_split=8;, score=0.966 total time=   4.2s
# [CV 5/5] END criterion=entropy, max_depth=3, min_samples_split=2;, score=0.897 total time=   1.1s
# [CV 1/5] END criterion=entropy, max_depth=3, min_samples_split=4;, score=0.919 total time=   1.1s
# [CV 2/5] END criterion=entropy, max_depth=3, min_samples_split=4;, score=0.907 total time=   1.1s
# [CV 3/5] END criterion=entropy, max_depth=3, min_samples_split=4;, score=0.912 total time=   1.3s
# [CV 4/5] END criterion=entropy, max_depth=3, min_samples_split=4;, score=0.913 total time=   1.1s
# [CV 5/5] END criterion=entropy, max_depth=3, min_samples_split=4;, score=0.911 total time=   1.1s
# [CV 1/5] END criterion=entropy, max_depth=3, min_samples_split=8;, score=0.926 total time=   1.1s
# [CV 2/5] END criterion=entropy, max_depth=3, min_samples_split=8;, score=0.911 total time=   1.1s
# [CV 4/5] END criterion=entropy, max_depth=3, min_samples_split=8;, score=0.903 total time=   1.1s
# [CV 5/5] END criterion=entropy, max_depth=3, min_samples_split=8;, score=0.901 total time=   1.1s
# [CV 3/5] END criterion=entropy, max_depth=3, min_samples_split=8;, score=0.902 total time=   1.3s
# [CV 1/5] END criterion=entropy, max_depth=10, min_samples_split=2;, score=0.954 total time=   2.5s
# [CV 2/5] END criterion=entropy, max_depth=10, min_samples_split=2;, score=0.950 total time=   2.5s
# [CV 4/5] END criterion=entropy, max_depth=10, min_samples_split=2;, score=0.948 total time=   2.5s
# [CV 3/5] END criterion=entropy, max_depth=10, min_samples_split=2;, score=0.948 total time=   2.7s
# [CV 5/5] END criterion=entropy, max_depth=10, min_samples_split=2;, score=0.952 total time=   2.5s
# [CV 1/5] END criterion=entropy, max_depth=10, min_samples_split=4;, score=0.954 total time=   2.5s
# [CV 2/5] END criterion=entropy, max_depth=10, min_samples_split=4;, score=0.947 total time=   2.5s
# [CV 3/5] END criterion=entropy, max_depth=10, min_samples_split=4;, score=0.946 total time=   2.6s
# [CV 4/5] END criterion=entropy, max_depth=10, min_samples_split=4;, score=0.949 total time=   2.5s
# [CV 5/5] END criterion=entropy, max_depth=10, min_samples_split=4;, score=0.958 total time=   2.5s
# [CV 1/5] END criterion=entropy, max_depth=10, min_samples_split=8;, score=0.951 total time=   2.5s
# [CV 2/5] END criterion=entropy, max_depth=10, min_samples_split=8;, score=0.949 total time=   2.5s
# [CV 3/5] END criterion=entropy, max_depth=10, min_samples_split=8;, score=0.945 total time=   2.6s
# [CV 4/5] END criterion=entropy, max_depth=10, min_samples_split=8;, score=0.949 total time=   2.5s
# [CV 5/5] END criterion=entropy, max_depth=10, min_samples_split=8;, score=0.952 total time=   2.5s
# [CV 1/5] END criterion=entropy, max_depth=20, min_samples_split=2;, score=0.964 total time=   4.5s
# [CV 2/5] END criterion=entropy, max_depth=20, min_samples_split=2;, score=0.960 total time=   4.5s
# [CV 4/5] END criterion=entropy, max_depth=20, min_samples_split=2;, score=0.960 total time=   4.6s
# [CV 3/5] END criterion=entropy, max_depth=20, min_samples_split=2;, score=0.963 total time=   4.7s
# [CV 5/5] END criterion=entropy, max_depth=20, min_samples_split=2;, score=0.966 total time=   4.6s
# [CV 1/5] END criterion=entropy, max_depth=20, min_samples_split=4;, score=0.963 total time=   4.5s
# [CV 2/5] END criterion=entropy, max_depth=20, min_samples_split=4;, score=0.961 total time=   4.5s
# [CV 3/5] END criterion=entropy, max_depth=20, min_samples_split=4;, score=0.963 total time=   4.7s
# [CV 4/5] END criterion=entropy, max_depth=20, min_samples_split=4;, score=0.960 total time=   4.6s
# [CV 5/5] END criterion=entropy, max_depth=20, min_samples_split=4;, score=0.964 total time=   4.6s
# [CV 1/5] END criterion=entropy, max_depth=20, min_samples_split=8;, score=0.964 total time=   4.4s
# [CV 2/5] END criterion=entropy, max_depth=20, min_samples_split=8;, score=0.960 total time=   4.4s
# [CV 3/5] END criterion=entropy, max_depth=20, min_samples_split=8;, score=0.962 total time=   3.9s
# [CV 4/5] END criterion=entropy, max_depth=20, min_samples_split=8;, score=0.959 total time=   2.9s
# [CV 5/5] END criterion=entropy, max_depth=20, min_samples_split=8;, score=0.965 total time=   2.8s
# Elasped time:  68.14190578460693

# %%
start = time()
clf = GridSearchCV(model, parameters, scoring='roc_auc', cv=StratifiedKFold(shuffle=True), n_jobs=8)
clf.fit(X_train, y_train)
elapsed = time() - start
print('Elasped time: ', elapsed)
# Out:
# Elasped time:  76.2965099811554

# %%
start = time()
clf = GridSearchCV(model, parameters, scoring='roc_auc', cv=StratifiedKFold(shuffle=True))
clf.fit(X_train, y_train)
elapsed = time() - start
print('Elasped time: ', elapsed)
