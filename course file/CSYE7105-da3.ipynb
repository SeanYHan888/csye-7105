# %% [markdown]
# CSYE7105 High Performance Parallel Machine Learning and AI
#
# Instructor: Dr. Handan Liu
#
# Lecture 12: Dask DataFrame in Parallel and Diagnostics

# %%
import dask

# %% [markdown]
# ## Dask DataFrame

# %%
df = dask.datasets.timeseries()

# %%
df
# Out:
# Dask DataFrame Structure:
#                   name     id        x        y
# npartitions=30
# 2000-01-01      string  int64  float64  float64
# 2000-01-02         ...    ...      ...      ...
# ...                ...    ...      ...      ...
# 2000-01-30         ...    ...      ...      ...
# 2000-01-31         ...    ...      ...      ...
# Dask Name: to_string_dtype, 2 expressions
# Expr=ArrowStringConversion(frame=Timeseries(487d096))

# %%
df.dtypes
# Out:
# name    string[pyarrow]
# id                int64
# x               float64
# y               float64
# dtype: object

# %%
df = dask.datasets.timeseries(start="2021-01-01", end="2022-01-01")
df
# Out:
# Dask DataFrame Structure:
#                    name     id        x        y
# npartitions=365
# 2021-01-01       string  int64  float64  float64
# 2021-01-02          ...    ...      ...      ...
# ...                 ...    ...      ...      ...
# 2021-12-31          ...    ...      ...      ...
# 2022-01-01          ...    ...      ...      ...
# Dask Name: to_string_dtype, 2 expressions
# Expr=ArrowStringConversion(frame=Timeseries(bd68993))

# %%
df.compute()
# Out:
#                         name    id         x         y
# timestamp
# 2021-01-01 00:00:00  Norbert   962 -0.580968  0.035411
# 2021-01-01 00:00:01    Laura   976  0.501258 -0.971124
# 2021-01-01 00:00:02   Yvonne   967 -0.791158 -0.199473
# 2021-01-01 00:00:03    Jerry  1042  0.306435  0.349104
# 2021-01-01 00:00:04    Wendy  1044  0.541958  0.936901
# ...                      ...   ...       ...       ...
# 2021-12-31 23:59:55   Ingrid   968 -0.526083  0.900046
# 2021-12-31 23:59:56   Hannah   972 -0.640473  0.628574
# 2021-12-31 23:59:57  Charlie   989  0.836480  0.513972
# 2021-12-31 23:59:58    Alice   998 -0.782194 -0.158081
# 2021-12-31 23:59:59    Frank   994  0.733854 -0.865034
#
# [31536000 rows x 4 columns]

# %% [markdown]
# ### Use Standard Pandas Operations.

# %%
df2 = df[df.y > 0]
df2
# Out:
# Dask DataFrame Structure:
#                    name     id        x        y
# npartitions=365
# 2021-01-01       string  int64  float64  float64
# 2021-01-02          ...    ...      ...      ...
# ...                 ...    ...      ...      ...
# 2021-12-31          ...    ...      ...      ...
# 2022-01-01          ...    ...      ...      ...
# Dask Name: getitem, 5 expressions
# Expr=Filter(frame=ArrowStringConversion(frame=Timeseries(bd68993)), predicate=ArrowStringConversion(frame=Timeseries(bd68993))['y'] > 0)

# %%
df3 = df2.groupby("name").x.std()
df3
# Out:
# Dask Series Structure:
# npartitions=1
#     float64
#         ...
# Dask Name: getitem, 8 expressions
# Expr=(((Filter(frame=ArrowStringConversion(frame=Timeseries(bd68993)), predicate=ArrowStringConversion(frame=Timeseries(bd68993))['y'] > 0))[['name', 'x']]).std(ddof=1, numeric_only=False, split_out=None, observed=False))['x']

# %%
computed_df = df3.compute()
# Out:
# ---------------------------------------------------------------------------
# FutureCancelledError                      Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 computed_df = df3.compute()
#
# File ~/.conda/envs/py2025/lib/python3.11/site-packages/dask/dataframe/dask_expr/_collection.py:489, in FrameBase.compute(self, fuse, concatenate, **kwargs)
#     487     out = out.repartition(npartitions=1)
#     488 out = out.optimize(fuse=fuse)
# --> 489 return DaskMethodsMixin.compute(out, **kwargs)
#
# File ~/.conda/envs/py2025/lib/python3.11/site-packages/dask/base.py:374, in DaskMethodsMixin.compute(self, **kwargs)
#     350 def compute(self, **kwargs):
#     351     """Compute this dask collection
#     352
#     353     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     372     dask.compute
#     373     """
# --> 374     (result,) = compute(self, traverse=False, **kwargs)
#     375     return result
#
# File ~/.conda/envs/py2025/lib/python3.11/site-packages/dask/base.py:662, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     659     postcomputes.append(x.__dask_postcompute__())
#     661 with shorten_traceback():
# --> 662     results = schedule(dsk, keys, **kwargs)
#     664 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/.conda/envs/py2025/lib/python3.11/site-packages/distributed/client.py:2426, in Client._gather(self, futures, errors, direct, local_worker)
#    2424     exception = st.exception
#    2425     traceback = st.traceback
# -> 2426     raise exception.with_traceback(traceback)
#    2427 if errors == "skip":
#    2428     bad_keys.add(key)
#
# FutureCancelledError: ('repartitiontofewer-2066cfe2a2aa1554008e5f6eb7a48f51', 0) cancelled for reason: scheduler-connection-lost.
# Client lost the connection to the scheduler. Please check your connection and re-run your work.

# %%
type(computed_df)
# Out:
# pandas.core.series.Series

# %%
computed_df
# Out:
# name
# Edith       0.576799
# Alice       0.577108
# Kevin       0.577916
# Michael     0.576494
# Patricia    0.577521
# Norbert     0.577804
# Zelda       0.577754
# Frank       0.577056
# Ray         0.577298
# Dan         0.577204
# Laura       0.578006
# Oliver      0.577421
# Sarah       0.577208
# Quinn       0.577273
# Ursula      0.577681
# Hannah      0.577062
# Jerry       0.576861
# Tim         0.576946
# Xavier      0.577405
# Yvonne      0.577425
# Victor      0.577647
# George      0.577448
# Wendy       0.577321
# Bob         0.577176
# Ingrid      0.577411
# Charlie     0.577878
# Name: x, dtype: float64

# %%
df4 = df.groupby("name").aggregate({"x": "sum", "y": "max"})

# %%
df4.compute()
# Out:
# ---------------------------------------------------------------------------
# FutureCancelledError                      Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df4.compute()
#
# File ~/.conda/envs/py2025/lib/python3.11/site-packages/dask/dataframe/dask_expr/_collection.py:489, in FrameBase.compute(self, fuse, concatenate, **kwargs)
#     487     out = out.repartition(npartitions=1)
#     488 out = out.optimize(fuse=fuse)
# --> 489 return DaskMethodsMixin.compute(out, **kwargs)
#
# File ~/.conda/envs/py2025/lib/python3.11/site-packages/dask/base.py:374, in DaskMethodsMixin.compute(self, **kwargs)
#     350 def compute(self, **kwargs):
#     351     """Compute this dask collection
#     352
#     353     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     372     dask.compute
#     373     """
# --> 374     (result,) = compute(self, traverse=False, **kwargs)
#     375     return result
#
# File ~/.conda/envs/py2025/lib/python3.11/site-packages/dask/base.py:662, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     659     postcomputes.append(x.__dask_postcompute__())
#     661 with shorten_traceback():
# --> 662     results = schedule(dsk, keys, **kwargs)
#     664 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/.conda/envs/py2025/lib/python3.11/site-packages/distributed/client.py:2426, in Client._gather(self, futures, errors, direct, local_worker)
#    2424     exception = st.exception
#    2425     traceback = st.traceback
# -> 2426     raise exception.with_traceback(traceback)
#    2427 if errors == "skip":
#    2428     bad_keys.add(key)
#
# FutureCancelledError: ('repartitiontofewer-560a600b0d91c31200d69700cee146bc', 0) cancelled for reason: scheduler-connection-lost.
# Client lost the connection to the scheduler. Please check your connection and re-run your work.

# %%
df4 = df4.repartition(npartitions=1)

joined = df.merge(
    df4, left_on="name", right_index=True, suffixes=("_original", "_aggregated") )

joined.head()

# %% [markdown]
# ## Dask Performance Reports

# %%
from dask.distributed import Client

# %%
client = Client(n_workers=2, threads_per_worker=2, memory_limit='8GB')
client
# Out:
# <Client: 'tcp://127.0.0.1:36153' processes=2 threads=4, memory=14.90 GiB>

# %%
from dask_jobqueue import SLURMCluster

# %%
cluster = SLURMCluster(cores=4, memory='25GB')
cluster.scale(jobs=1)
# Out:
# /home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 46461 instead
#   warnings.warn(
# 2025-10-14 14:10:24,398 - distributed.protocol.core - CRITICAL - Failed to deserialize
# Traceback (most recent call last):
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 128, in unpackb
#     ret = unpacker._unpack()
#           ^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 565, in _unpack
#     ret.append(self._unpack(EX_CONSTRUCT))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 585, in _unpack
#     key = self._unpack(EX_CONSTRUCT)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 546, in _unpack
#     typ, n, obj = self._read_header()
#                   ^^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 447, in _read_header
#     self._reserve(1)
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 420, in _reserve
#     raise OutOfData
# msgpack.exceptions.OutOfData
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/protocol/core.py", line 175, in loads
#     return msgpack.loads(
#            ^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 130, in unpackb
#     raise ValueError("Unpack failed: incomplete input")
# ValueError: Unpack failed: incomplete input
# 2025-10-14 14:10:24,404 - distributed.core - ERROR - Exception while handling op register-client
# Traceback (most recent call last):
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 128, in unpackb
#     ret = unpacker._unpack()
#           ^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 565, in _unpack
#     ret.append(self._unpack(EX_CONSTRUCT))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 585, in _unpack
#     key = self._unpack(EX_CONSTRUCT)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 546, in _unpack
#     typ, n, obj = self._read_header()
#                   ^^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 447, in _read_header
#     self._reserve(1)
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 420, in _reserve
#     raise OutOfData
# msgpack.exceptions.OutOfData
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/core.py", line 834, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/scheduler.py", line 5923, in add_client
#     await self.handle_stream(comm=comm, extra={"client": client})
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/core.py", line 889, in handle_stream
#     msgs = await comm.read()
#            ^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/comm/tcp.py", line 248, in read
#     msg = await from_frames(
#           ^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/comm/utils.py", line 78, in from_frames
#     res = _from_frames()
#           ^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/comm/utils.py", line 61, in _from_frames
#     return protocol.loads(
#            ^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/protocol/core.py", line 175, in loads
#     return msgpack.loads(
#            ^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 130, in unpackb
#     raise ValueError("Unpack failed: incomplete input")
# ValueError: Unpack failed: incomplete input
# Task exception was never retrieved
# future: <Task finished name='Task-67062' coro=<Server._handle_comm() done, defined at /home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/core.py:740> exception=ValueError('Unpack failed: incomplete input')>
# Traceback (most recent call last):
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 128, in unpackb
#     ret = unpacker._unpack()
#           ^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 565, in _unpack
#     ret.append(self._unpack(EX_CONSTRUCT))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 585, in _unpack
#     key = self._unpack(EX_CONSTRUCT)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 546, in _unpack
#     typ, n, obj = self._read_header()
#                   ^^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 447, in _read_header
#     self._reserve(1)
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 420, in _reserve
#     raise OutOfData
# msgpack.exceptions.OutOfData
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/core.py", line 834, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/scheduler.py", line 5923, in add_client
#     await self.handle_stream(comm=comm, extra={"client": client})
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/core.py", line 889, in handle_stream
#     msgs = await comm.read()
#            ^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/comm/tcp.py", line 248, in read
#     msg = await from_frames(
#           ^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/comm/utils.py", line 78, in from_frames
#     res = _from_frames()
#           ^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/comm/utils.py", line 61, in _from_frames
#     return protocol.loads(
#            ^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/protocol/core.py", line 175, in loads
#     return msgpack.loads(
#            ^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 130, in unpackb
#     raise ValueError("Unpack failed: incomplete input")
# ValueError: Unpack failed: incomplete input
# 2025-10-14 14:10:53,324 - distributed.protocol.core - CRITICAL - Failed to deserialize
# Traceback (most recent call last):
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 128, in unpackb
#     ret = unpacker._unpack()
#           ^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 565, in _unpack
#     ret.append(self._unpack(EX_CONSTRUCT))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 585, in _unpack
#     key = self._unpack(EX_CONSTRUCT)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 546, in _unpack
#     typ, n, obj = self._read_header()
#                   ^^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 447, in _read_header
#     self._reserve(1)
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 420, in _reserve
#     raise OutOfData
# msgpack.exceptions.OutOfData
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/protocol/core.py", line 175, in loads
#     return msgpack.loads(
#            ^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 130, in unpackb
#     raise ValueError("Unpack failed: incomplete input")
# ValueError: Unpack failed: incomplete input
# 2025-10-14 14:10:53,327 - distributed.core - ERROR - Exception while handling op register-client
# Traceback (most recent call last):
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 128, in unpackb
#     ret = unpacker._unpack()
#           ^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 565, in _unpack
#     ret.append(self._unpack(EX_CONSTRUCT))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 585, in _unpack
#     key = self._unpack(EX_CONSTRUCT)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 546, in _unpack
#     typ, n, obj = self._read_header()
#                   ^^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 447, in _read_header
#     self._reserve(1)
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 420, in _reserve
#     raise OutOfData
# msgpack.exceptions.OutOfData
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/core.py", line 834, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/scheduler.py", line 5923, in add_client
#     await self.handle_stream(comm=comm, extra={"client": client})
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/core.py", line 889, in handle_stream
#     msgs = await comm.read()
#            ^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/comm/tcp.py", line 248, in read
#     msg = await from_frames(
#           ^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/comm/utils.py", line 78, in from_frames
#     res = _from_frames()
#           ^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/comm/utils.py", line 61, in _from_frames
#     return protocol.loads(
#            ^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/protocol/core.py", line 175, in loads
#     return msgpack.loads(
#            ^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 130, in unpackb
#     raise ValueError("Unpack failed: incomplete input")
# ValueError: Unpack failed: incomplete input
# Task exception was never retrieved
# future: <Task finished name='Task-166999' coro=<Server._handle_comm() done, defined at /home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/core.py:740> exception=ValueError('Unpack failed: incomplete input')>
# Traceback (most recent call last):
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 128, in unpackb
#     ret = unpacker._unpack()
#           ^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 565, in _unpack
#     ret.append(self._unpack(EX_CONSTRUCT))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 585, in _unpack
#     key = self._unpack(EX_CONSTRUCT)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 546, in _unpack
#     typ, n, obj = self._read_header()
#                   ^^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 447, in _read_header
#     self._reserve(1)
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 420, in _reserve
#     raise OutOfData
# msgpack.exceptions.OutOfData
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/core.py", line 834, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/scheduler.py", line 5923, in add_client
#     await self.handle_stream(comm=comm, extra={"client": client})
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/core.py", line 889, in handle_stream
#     msgs = await comm.read()
#            ^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/comm/tcp.py", line 248, in read
#     msg = await from_frames(
#           ^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/comm/utils.py", line 78, in from_frames
#     res = _from_frames()
#           ^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/comm/utils.py", line 61, in _from_frames
#     return protocol.loads(
#            ^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/protocol/core.py", line 175, in loads
#     return msgpack.loads(
#            ^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 130, in unpackb
#     raise ValueError("Unpack failed: incomplete input")
# ValueError: Unpack failed: incomplete input
# 2025-10-14 14:42:48,727 - distributed.protocol.core - CRITICAL - Failed to deserialize
# Traceback (most recent call last):
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 128, in unpackb
#     ret = unpacker._unpack()
#           ^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 565, in _unpack
#     ret.append(self._unpack(EX_CONSTRUCT))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 585, in _unpack
#     key = self._unpack(EX_CONSTRUCT)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 546, in _unpack
#     typ, n, obj = self._read_header()
#                   ^^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 447, in _read_header
#     self._reserve(1)
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 420, in _reserve
#     raise OutOfData
# msgpack.exceptions.OutOfData
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/protocol/core.py", line 175, in loads
#     return msgpack.loads(
#            ^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 130, in unpackb
#     raise ValueError("Unpack failed: incomplete input")
# ValueError: Unpack failed: incomplete input
# 2025-10-14 14:42:48,732 - distributed.core - ERROR - Exception while handling op register-client
# Traceback (most recent call last):
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 128, in unpackb
#     ret = unpacker._unpack()
#           ^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 565, in _unpack
#     ret.append(self._unpack(EX_CONSTRUCT))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 585, in _unpack
#     key = self._unpack(EX_CONSTRUCT)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 546, in _unpack
#     typ, n, obj = self._read_header()
#                   ^^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 447, in _read_header
#     self._reserve(1)
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 420, in _reserve
#     raise OutOfData
# msgpack.exceptions.OutOfData
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/core.py", line 834, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/scheduler.py", line 5923, in add_client
#     await self.handle_stream(comm=comm, extra={"client": client})
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/core.py", line 889, in handle_stream
#     msgs = await comm.read()
#            ^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/comm/tcp.py", line 248, in read
#     msg = await from_frames(
#           ^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/comm/utils.py", line 78, in from_frames
#     res = _from_frames()
#           ^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/comm/utils.py", line 61, in _from_frames
#     return protocol.loads(
#            ^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/protocol/core.py", line 175, in loads
#     return msgpack.loads(
#            ^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 130, in unpackb
#     raise ValueError("Unpack failed: incomplete input")
# ValueError: Unpack failed: incomplete input
# Task exception was never retrieved
# future: <Task finished name='Task-177008' coro=<Server._handle_comm() done, defined at /home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/core.py:740> exception=ValueError('Unpack failed: incomplete input')>
# Traceback (most recent call last):
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 128, in unpackb
#     ret = unpacker._unpack()
#           ^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 565, in _unpack
#     ret.append(self._unpack(EX_CONSTRUCT))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 585, in _unpack
#     key = self._unpack(EX_CONSTRUCT)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 546, in _unpack
#     typ, n, obj = self._read_header()
#                   ^^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 447, in _read_header
#     self._reserve(1)
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 420, in _reserve
#     raise OutOfData
# msgpack.exceptions.OutOfData
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/core.py", line 834, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/scheduler.py", line 5923, in add_client
#     await self.handle_stream(comm=comm, extra={"client": client})
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/core.py", line 889, in handle_stream
#     msgs = await comm.read()
#            ^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/comm/tcp.py", line 248, in read
#     msg = await from_frames(
#           ^^^^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/comm/utils.py", line 78, in from_frames
#     res = _from_frames()
#           ^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/comm/utils.py", line 61, in _from_frames
#     return protocol.loads(
#            ^^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/distributed/protocol/core.py", line 175, in loads
#     return msgpack.loads(
#            ^^^^^^^^^^^^^^
#   File "/home/h.liu/.conda/envs/py2025/lib/python3.11/site-packages/msgpack/fallback.py", line 130, in unpackb
#     raise ValueError("Unpack failed: incomplete input")
# ValueError: Unpack failed: incomplete input

# %%
client=Client(cluster)
client
# Out:
# <Client: 'tcp://10.99.249.61:42635' processes=0 threads=0, memory=0 B>

# %%
# benchmark
import dask
from dask.distributed import performance_report

with performance_report(filename="dask_report_2.html"):
    df = dask.datasets.timeseries(start="2021-01-01", end="2022-01-01")
    df = df.persist()
    df.groupby(df.name).x.mean().compute()
